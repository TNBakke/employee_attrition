# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/employee_attrition.csv")

# %%
plt.rc("font", size=16)

# %%
import seaborn as sns

# %%
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
import seaborn as sns
import pandas as pd
sns.set(rc={"figure.dpi":400, 'savefig.dpi':400})
fig, ax = plt.subplots(figsize=(10,10))

y = [(25/55),(58/286),(127/766), (27/126)]
x = np.arange(len(y))
# df.drop(df.columns[0], axis=1,inplace=True)
ax.bar(x,y)
ax.set_xticks(x)
# ax = sns.countplot(x="BusinessTravel", hue = 'Attrition', data=df)
# ax.set(xlabel='Business Travel', ylabel='Employee Count')
ax.set_xlabel("Work Life Balance (4 Highest Rating)", fontsize=16)
ax.set_ylabel("Attrition Percentage", fontsize=16)
ax.axes.set_title("Employee Attrition vs. Work Life Balance", fontsize=16)
ax.set_xticklabels(['Rating = 1','Rating = 2', 'Rating = 3', 'Rating = 4'])
ax.tick_params(labelsize=12)
# sns.set(rc={'figure.figsize':(12,8)})
# for p in ax.patches:
#     ax.annotate('{}'.format(p.get_height()), (p.get_x(), p.get_height()+1))

# %%
import seaborn as sns
import pandas as pd
sns.set(rc={"figure.dpi":400, 'savefig.dpi':400})
fig, ax = plt.subplots(figsize=(10,10))

y = [(127/289),(110/994)]
x = np.arange(len(y))
# df.drop(df.columns[0], axis=1,inplace=True)
ax.bar(x,y)
ax.set_xticks(x)
# ax = sns.countplot(x="BusinessTravel", hue = 'Attrition', data=df)
# ax.set(xlabel='Business Travel', ylabel='Employee Count')
ax.set_xlabel("Overtime", fontsize=16)
ax.set_ylabel("Attrition Percentage", fontsize=16)
ax.axes.set_title("Employee Attrition vs. Overtime Work", fontsize=16)
ax.set_xticklabels(['Yes','No'])
ax.tick_params(labelsize=12)
# sns.set(rc={'figure.figsize':(12,8)})
# for p in ax.patches:
#     ax.annotate('{}'.format(p.get_height()), (p.get_x(), p.get_height()+1))

# %%
import seaborn as sns
import pandas as pd
sns.set(rc={"figure.dpi":400, 'savefig.dpi':400})
fig, ax = plt.subplots(figsize=(10,10))

y = [(120/350),(84/589),(33/294)]
x = np.arange(len(y))
# df.drop(df.columns[0], axis=1,inplace=True)
ax.bar(x,y)
ax.set_xticks(x)
# ax = sns.countplot(x="BusinessTravel", hue = 'Attrition', data=df)
# ax.set(xlabel='Business Travel', ylabel='Employee Count')
ax.set_xlabel("Marital Status", fontsize=16)
ax.set_ylabel("Attrition Percentage", fontsize=16)
ax.axes.set_title("Employee Attrition vs. Marital Status", fontsize=16)
ax.set_xticklabels(['Single','Married', 'Divorced'])
ax.tick_params(labelsize=12)
# sns.set(rc={'figure.figsize':(12,8)})
# for p in ax.patches:
#     ax.annotate('{}'.format(p.get_height()), (p.get_x(), p.get_height()+1))

# %%
import seaborn as sns
import pandas as pd
sns.set(rc={"figure.dpi":400, 'savefig.dpi':400})
fig, ax = plt.subplots(figsize=(10,10))

y = [(69/208),(156/887),(12/138)]
x = np.arange(len(y))
# df.drop(df.columns[0], axis=1,inplace=True)
ax.bar(x,y)
ax.set_xticks(x)
# ax = sns.countplot(x="BusinessTravel", hue = 'Attrition', data=df)
# ax.set(xlabel='Business Travel', ylabel='Employee Count')
ax.set_xlabel("Business Travel", fontsize=16)
ax.set_ylabel("Attrition Percentage", fontsize=16)
ax.axes.set_title("Employee Attrition vs. Business Travel", fontsize=16)
ax.set_xticklabels(['Travel Frequently','Travel Rarely', 'Non-Travel'])
ax.tick_params(labelsize=12)
# sns.set(rc={'figure.figsize':(12,8)})
# for p in ax.patches:
#     ax.annotate('{}'.format(p.get_height()), (p.get_x(), p.get_height()+1))

# %%
import seaborn as sns
import pandas as pd
sns.set(rc={"figure.dpi":400, 'savefig.dpi':400})

df.drop(df.columns[0], axis=1,inplace=True)

ax = sns.countplot(x="WorkLifeBalance", hue = 'Attrition', data=df)
# ax.set(xlabel='Business Travel', ylabel='Employee Count')
ax.set_xlabel("Work Life Balance (4 Highest Score)", fontsize=16)
ax.set_ylabel("Employee Count", fontsize=16)
ax.axes.set_title("Employee Attrition vs. Work Life Balance", fontsize=16)
# ax.set_xticklabels(['No','Yes'])
ax.tick_params(labelsize=12)
sns.set(rc={'figure.figsize':(12,8)})
for p in ax.patches:
    ax.annotate('{}'.format(p.get_height()), (p.get_x(), p.get_height()+1))

# %%
import seaborn as sns
import pandas as pd
sns.set(rc={"figure.dpi":400, 'savefig.dpi':400})

df.drop(df.columns[0], axis=1,inplace=True)

ax = sns.countplot(x="MaritalStatus", hue = 'Attrition', data=df)
# ax.set(xlabel='Business Travel', ylabel='Employee Count')
ax.set_xlabel("Marital Status", fontsize=16)
ax.set_ylabel("Employee Count", fontsize=16)
ax.axes.set_title("Employee Attrition vs. Marital Status", fontsize=16)
# ax.set_xticklabels(['No','Yes'])
ax.tick_params(labelsize=12)
sns.set(rc={'figure.figsize':(12,8)})
for p in ax.patches:
    ax.annotate('{}'.format(p.get_height()), (p.get_x(), p.get_height()+1))

# %%
plt.figure(figsize=(10,6), dpi=400)
plt.style.use('seaborn-colorblind')
plt.grid(True, alpha=0.5)
sns.kdeplot(df.loc[df['Attrition'] == 'No', 'Age'], label = 'Active Employee')
sns.kdeplot(df.loc[df['Attrition'] == 'Yes', 'Age'], label = 'Ex-Employees')
plt.legend(loc='upper right')
plt.xlim(left=18, right=60)
plt.xlabel('Age (years)')
plt.ylabel('Density')
plt.title('Age Distribution in Percent by Attrition Status');

# %%
sns.countplot(x='Attrition', data=df)
plt.show()

# %%
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
# sns.countplot(x='Attrition', data=df)
# plt.show()

# %%
# %matplotlib inline
pd.crosstab(df.Age,df.Attrition).plot(kind='bar', figsize=(15,10))
plt.title('Attrition by Age')
plt.xlabel('Age')
plt.ylabel('Employee Count')
plt.show()

# %%
# %matplotlib inline
# pd.crosstab(df.DistanceFromHome,df.Attrition).plot(kind='bar', figsize=(15,10))
# plt.title('Attrition by Commute Length')
# plt.xlabel('Commute Length (Miles)')
# plt.ylabel('Employee Count')
# plt.show()

# %%
# %matplotlib inline
pd.crosstab(df.Department,df.Attrition).plot(kind='bar', figsize=(15,10))
plt.title('Attrition by Department')
plt.xlabel('Department')
plt.ylabel('Employee Count')
plt.xticks(rotation=45)
plt.show()

# %%
# %matplotlib inline
pd.crosstab(df.OverTime,df.Attrition).plot(kind='bar', figsize=(4,4))
plt.title('Attrition by Overtime Work')
plt.xlabel('Overtime')
plt.ylabel('Employee Count')
plt.xticks(rotation=45)
plt.show()

# %%
# %matplotlib inline
pd.crosstab(df.DistanceFromHome,df.Attrition).plot(kind='bar', figsize=(15,10))
plt.title('Attrition by Work Life Balance')
plt.xlabel('Work Life Balance (4 is Best)')
plt.ylabel('Employee Count')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
plt.rc("font", size=16)
plt.style.use('ggplot')

# %%
df = pd.read_csv("./data/employee_attrition.csv")

disc_col = []
for column in df.columns:
    if df[column].dtypes != object and df[column].nunique() < 30:
        print(f"{column} : {df[column].unique()}")
        disc_col.append(column)
        print("====================================")
disc_col.remove('Attrition')

plt.figure(figsize=(20, 20))
# Out:
# DistanceFromHome : [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
# ...
# Education : [2 1 4 3 5]
# ...
# EmployeeCount : [1]
# ...
# EnvironmentSatisfaction : [2 3 4 1]
# ...
# JobInvolvement : [3 2 4 1]
# ...
# JobLevel : [2 1 3 4 5]
# ...
# JobSatisfaction : [4 2 3 1]
# ...
# NumCompaniesWorked : [8 1 6 9 0 4 5 2 7 3]
# ...
# PercentSalaryHike : [11 23 15 12 13 20 22 21 17 14 16 18 19 24 25]
# ...
# PerformanceRating : [3 4]
# ...
# RelationshipSatisfaction : [1 4 2 3]
# ...
# StandardHours : [80]
# ...
# StockOptionLevel : [0 1 3 2]
# ...
# TrainingTimesLastYear : [0 3 2 5 1 4 6]
# ...
# WorkLifeBalance : [1 3 2 4]
# ...
# YearsInCurrentRole : [ 4  7  0  2  5  9  8  3  6 13  1 15 14 16 11 10 12 18 17]
# ...
# YearsSinceLastPromotion : [ 0  1  3  2  7  4  8  6  5 15  9 13 12 10 11 14]
# ...
# YearsWithCurrManager : [ 5  7  0  2  6  8  3 11 17  1  4 12  9 10 15 13 16 14]
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...

# %%
for i, column in enumerate(disc_col, 1):
    plt.subplot(4, 4, i)
    df[df["Attrition"] == 'No'][column].hist(bins=35, color='blue', label='Attrition = NO', alpha=0.6)
    df[df["Attrition"] == 'Yes'][column].hist(bins=35, color='red', label='Attrition = YES', alpha=0.6)
    plt.legend()
    plt.xlabel(column)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f0d93b7e7a44> in <module>
#       1 for i, column in enumerate(disc_col, 1):
# ----> 2     plt.subplot(4, 4, i)
#       3     df[df["Attrition"] == 'No'][column].hist(bins=35, color='blue', label='Attrition = NO', alpha=0.6)
#       4     df[df["Attrition"] == 'Yes'][column].hist(bins=35, color='red', label='Attrition = YES', alpha=0.6)
#       5     plt.legend()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1124
#    1125     fig = gcf()
# -> 1126     ax = fig.add_subplot(*args, **kwargs)
#    1127     bbox = ax.bbox
#    1128     axes_to_delete = []
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
# ...

# %%
cont_col = []
for column in df.columns:
    if df[column].dtypes != object and df[column].nunique() > 30:
        print(f"{column} : Minimum: {df[column].min()}, Maximum: {df[column].max()}")
        cont_col.append(column)
        print("====================================")

plt.figure(figsize=(20, 10))

for i, column in enumerate(cont_col, 1):
    plt.subplot(2, 4, i)
    df[df["Attrition"] == 'No'][column].hist(bins=35, color='blue', label='Attrition = NO', alpha=0.6)
    df[df["Attrition"] == 'Yes'][column].hist(bins=35, color='red', label='Attrition = YES', alpha=0.6)
    plt.legend()
    plt.xlabel(column)
# Out:
# Age : Minimum: 18, Maximum: 60
# ...
# DailyRate : Minimum: 102, Maximum: 1499
# ...
# EmployeeNumber : Minimum: 1, Maximum: 2068
# ...
# HourlyRate : Minimum: 30, Maximum: 100
# ...
# MonthlyIncome : Minimum: 1009, Maximum: 19999
# ...
# MonthlyRate : Minimum: 2094, Maximum: 26999
# ...
# TotalWorkingYears : Minimum: 0, Maximum: 40
# ...
# YearsAtCompany : Minimum: 0, Maximum: 40
# ...

# %%
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv("./data/employee_attrition.csv")

# %%
total_records = len(df)

# %%
columns = ["Age","MaritalStatus","WorkLifeBalance","DistanceFromHome","MonthlyIncome",
           "YearsAtCompany","BusinessTravel","Department"]

# %%
sns.countplot(x='BusinessTravel', hue='Attrition', data=df)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 10))
# plt.rcParams.update({"font", size=22})
plt.style.use('ggplot')

for i, column in enumerate(columns, 1):
    plt.subplot(2, 4, i)
    df[df["Attrition"] == 'No'][column].hist(color='darkblue', label='Attrition = No',alpha=0.7)
    df[df["Attrition"] == 'Yes'][column].hist(color='darkred', label='Attrition = Yes', alpha=0.8)
    plt.legend()
    plt.xlabel(column, fontsize=16)
    plt.xticks(fontsize=12)
    plt.ylabel("Employee Count", fontsize=16)
    plt.tight_layout()

# %%
import seaborn as sns
import pandas as pd
sns.set(rc={"figure.dpi":400, 'savefig.dpi':400})

df = pd.read_csv("../data/clean_one_hot_emp_data.csv")
df.drop(df.columns[0], axis=1,inplace=True)

ax = sns.countplot(x="business_travel", hue = 'attrition', data=df)
# ax.set(xlabel='Business Travel', ylabel='Employee Count')
ax.set_xlabel("Business Travel", fontsize=16)
ax.set_ylabel("Employee Count", fontsize=16)
ax.axes.set_title("Employee Attrition vs. Business Travel", fontsize=16)
ax.set_xticklabels(['Non-Travel','Travel Rarely','Travel Frequently'])
ax.tick_params(labelsize=12)
sns.set(rc={'figure.figsize':(12,8)})
for p in ax.patches:
    ax.annotate('{}'.format(p.get_height()), (p.get_x(), p.get_height()+1))

# %%
df.head()
# Out:
#    age  attrition  business_travel  daily_rate  distance_from_home  education  \
# 0   41          1                1        1102                   1          2
# 1   49          0                2         279                   8          1
# 2   37          1                1        1373                   2          2
# 3   33          0                2        1392                   3          4
# 4   27          0                1         591                   2          1
#
#    environment_satisfaction  gender  hourly_rate  job_involvement  ...  \
# 0                         2       0           94                3  ...
# 1                         3       1           61                2  ...
# 2                         4       1           92                2  ...
# 3                         4       0           56                3  ...
# 4                         1       1           40                3  ...
#
# ...

# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv("../data/clean_one_hot_emp_data.csv")
df.drop(df.columns[0], axis=1,inplace=True)

ax = sns.countplot(x="age", hue = 'attrition', data=df)
# ax.set(xlabel='Business Travel', ylabel='Employee Count')
ax.set_xlabel("Age", fontsize=16)
ax.set_ylabel("Employee Count", fontsize=16)
ax.axes.set_title("Employee Attrition vs. Age", fontsize=16)
# ax.set_xticklabels(['Non-Travel','Travel Rarely','Travel Frequently'])
ax.tick_params(labelsize=12)
for item in ax.get_xticklabels():
    item.set_rotation(70)
sns.set(rc={'figure.figsize':(15,10)})
# for p in ax.patches:
#     ax.annotate('{}'.format(p.get_height()), (p.get_x(), p.get_height()+1))

# %%
# %matplotlib inline

# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt

# tips = sns.load_dataset("tips")
# tips.loc[tips.time == "Lunch", "total_bill"] *= 2

# def multihist(x, hue, n_bins=10, color=None, **kws):
#     bins = np.linspace(x.min(), x.max(), n_bins)
#     for _, x_i in x.groupby(hue):
#         plt.hist(x_i, bins, **kws)

# g = sns.FacetGrid(df, row="time", sharex=False)
# g.map(multihist, "total_bill", "smoker", alpha=.5, edgecolor="w")

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.hist(df.age, bin

You'll need to define a wrapper function for plt.hist that does the hue grouping itself, something like

# %matplotlib inline

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
tips.loc[tips.time == "Lunch", "total_bill"] *= 2

def multihist(x, hue, n_bins=10, color=None, **kws):
    bins = np.linspace(x.min(), x.max(), n_bins)
    for _, x_i in x.groupby(hue):
        plt.hist(x_i, bins, **kws)

g = sns.FacetGrid(tips, row="time", sharex=False)
g.map(multihist, "total_bill", "smoker", alpha=.5, edgecolor="w")


You'll need to define a wrapper function for plt.hist that does the hue grouping itself, something like

# %matplotlib inline

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
tips.loc[tips.time == "Lunch", "total_bill"] *= 2

def multihist(x, hue, n_bins=10, color=None, **kws):
    bins = np.linspace(x.min(), x.max(), n_bins)
    for _, x_i in x.groupby(hue):
        plt.hist(x_i, bins, **kws)

g = sns.FacetGrid(tips, row="time", sharex=False)
g.map(multihist, "total_bill", "smoker", alpha=.5, edgecolor="w")
)

# %%
import seaborn as sns
import pandas as pd
sns.set(rc={"figure.dpi":400, 'savefig.dpi':400})

df = pd.read_csv("../data/clean_one_hot_emp_data.csv")
df.drop(df.columns[0], axis=1,inplace=True)

ax = sns.countplot(x="over_time", hue = 'attrition', data=df)
# ax.set(xlabel='Business Travel', ylabel='Employee Count')
ax.set_xlabel("Overtime", fontsize=16)
ax.set_ylabel("Employee Count", fontsize=16)
ax.axes.set_title("Employee Attrition vs. Overtime", fontsize=16)
ax.set_xticklabels(['No','Yes'])
ax.tick_params(labelsize=12)
sns.set(rc={'figure.figsize':(12,8)})
for p in ax.patches:
    ax.annotate('{}'.format(p.get_height()), (p.get_x(), p.get_height()+1))

# %%
import seaborn as sns
import pandas as pd
sns.set(rc={"figure.dpi":400, 'savefig.dpi':400})

df = pd.read_csv("../data/clean_one_hot_emp_data.csv")
df.drop(df.columns[0], axis=1,inplace=True)

ax = sns.countplot(x='attrition', data=df)
# ax.set(xlabel='Business Travel', ylabel='Employee Count')
ax.set_xlabel("Employee Left Company", fontsize=16)
ax.set_ylabel("Employee Count", fontsize=16)
ax.axes.set_title("Current Rate of Employee Attrition", fontsize=16)
ax.set_xticklabels(['No','Yes'])
ax.tick_params(labelsize=12)
sns.set(rc={'figure.figsize':(12,8)})
for p in ax.patches:
    ax.annotate('{}'.format(p.get_height()), (p.get_x(), p.get_height()+1))
    
# sns.countplot(x='Attrition', data=df)
# plt.show()

# %%
import seaborn as sns
import pandas as pd
sns.set(rc={"figure.dpi":400, 'savefig.dpi':400})

df = pd.read_csv("../data/clean_one_hot_emp_data.csv")
df.drop(df.columns[0], axis=1,inplace=True)

ax = sns.countplot(x="MaritalStatus", hue = 'Attrition', data=df)
# ax.set(xlabel='Business Travel', ylabel='Employee Count')
ax.set_xlabel("Marital Status", fontsize=16)
ax.set_ylabel("Employee Count", fontsize=16)
ax.axes.set_title("Employee Attrition vs. Marital Status", fontsize=16)
# ax.set_xticklabels(['No','Yes'])
ax.tick_params(labelsize=12)
sns.set(rc={'figure.figsize':(12,8)})
for p in ax.patches:
    ax.annotate('{}'.format(p.get_height()), (p.get_x(), p.get_height()+1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-017aa89d43da> in <module>
#       6 df.drop(df.columns[0], axis=1,inplace=True)
#       7
# ----> 8 ax = sns.countplot(x="MaritalStatus", hue = 'Attrition', data=df)
#       9 # ax.set(xlabel='Business Travel', ylabel='Employee Count')
#      10 ax.set_xlabel("Marital Status", fontsize=16)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3587         estimator, ci, n_boot, units, seed,
# ...

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'business_travel', 'daily_rate',
#        'distance_from_home', 'education', 'environment_satisfaction', 'gender',
#        'hourly_rate', 'job_involvement', 'job_level', 'job_satisfaction',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over_time',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_curr_manager',
#        'job_role_human resources', 'job_role_laboratory technician',
#        'job_role_manager', 'job_role_manufacturing director',
#        'job_role_research director', 'job_role_research scientist',
#        'job_role_sales executive', 'job_role_sales representative',
#        'department_research & development', 'department_sales',
# ...
